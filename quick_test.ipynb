# %% [markdown]
# ## File to quick test/run small snippets of code

# %%
import game_utils as gu
import numpy as np
# Out:
# Running cells with 'testenv (Python 3.8.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n testenv ipykernel --update-deps --force-reinstall'

# %%
print(3%2)
# Out:
# Running cells with '.venv (Python 3.13.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Nico/Studium - Master/2. semester/Programming Course and Project/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
